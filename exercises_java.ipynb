# %%
# Basic Function Exercises


# Implement a function to convert kilograms to grams.

# Implement a function to convert reais to dollars.

# Implement a function to convert dollars to reais.

# Implement a function to check if a student has FAILED based on 3 grades, considering that the passing average is 5 or higher.

# Implement a function to calculate an employee’s net salary based on their base salary, monthly bonus (in %), and total deductions.
# Example:
# Salary: 1000 reais
# Bonus: 10 percent
# Deductions: 300 reais
# Result:
# 800


# Implement a function to check if a person has a fever, considering that a fever is defined as 37°C or higher.


# Implement a function to check whether someone should go to the park or not.
# To go to the park, the temperature must be between 23°C and 30°C (inclusive).


# Implement a function that returns a welcome message based on a student’s name.
# Example:
# "Welcome Bruno!"


# Implement a function that returns a formatted message showing the installment payments of a purchase,
# based on the total purchase amount and the number of installments.
# Example response:
# "Your purchase of R$1200 in 10 installments of R$120 has been completed."

# %%
# Condition


# Implement a function to check which is greater between two numbers. The function must return a message in the format:
# "The number X is greater than Y"


# Implement a function to check which is greater between two numbers. If the numbers are equal, the function must return the message:
# "The numbers are equal"


# Implement a function to check which is greater among three numbers. The function must return a message in the format:
# "The number X is greater than Y and Z"
# If the numbers are equal, the function must return:
# "The numbers are equal"


# Implement a function that returns a message with the action a pedestrian should take when seeing their traffic light. Possible actions:
# Red → Wait
# Green → Cross
# If the color is different, the function must return an error with the message:
# "Traffic light malfunction"


# Implement a function that reports the status of a family budget based on total income and expenses.
# If income > expenses → "You are within budget!"
# Otherwise → "You are over budget! Do not spend more!"
